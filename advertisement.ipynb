# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
df = pd.read_csv('Advertising.csv',index_col = 0)
df.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
sns.boxplot(data = df.iloc[:,0:3])
plt.show()

# %%
sns.distplot(df['newspaper'],kde=False)

# %%
sns.pairplot(df,x_vars=['TV','radio','newspaper'],y_vars='sales',kind='reg',aspect=0.7,size=7)
# Out:
# C:\Users\USER\Anaconda3\envs\myenv\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
df.shape
# Out:
# (200, 4)

# %%
X=df.drop('sales',axis=1)
print(X.head())
print(type(X))
print(X.shape)
# Out:
#       TV  radio  newspaper
# 1  230.1   37.8       69.2
# 2   44.5   39.3       45.1
# 3   17.2   45.9       69.3
# 4  151.5   41.3       58.5
# 5  180.8   10.8       58.4
# <class 'pandas.core.frame.DataFrame'>
# (200, 3)

# %%
y=df.sales
print(y.head())
print(type(y))
print(y.shape)
# Out:
# 1    22.1
# 2    10.4
# 3     9.3
# 4    18.5
# 5    12.9
# Name: sales, dtype: float64
# <class 'pandas.core.series.Series'>
# (200,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
linreg=LinearRegression()
linreg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred = linreg.predict(X_test)

# %%
print(linreg.coef_)
print(linreg.intercept_)
# Out:
# [0.04391531 0.20027962 0.00184368]
# 2.880255286331323

# %%
sns.scatterplot(x=y_test,y=y_pred,palette='spring')

# %%
X = df.drop(['sales','newspaper'],axis=1)
X.head()
# Out:
#       TV  radio
# 1  230.1   37.8
# 2   44.5   39.3
# 3   17.2   45.9
# 4  151.5   41.3
# 5  180.8   10.8

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,shuffle=True,random_state=0)

# %%
linreg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred = linreg.predict(X_test)

# %%
sns.scatterplot(x=y_test,y=y_pred,palette='winter')

# %%
print(linreg.coef_)
print(linreg.intercept_)
# Out:
# [0.04396652 0.20099526]
# 2.909895690512924
